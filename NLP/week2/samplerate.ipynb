# %%
import librosa
def sample_rate(frequency, duration):
    sample_rate = 1000
    data = librosa.tone(frequency, sr=sample_rate, duration=duration)
    nyquist_freq = sample_rate / 2

    return data, sample_rate, nyquist_freq, frequency

data, sr, nyquist, frequency = sample_rate(1000, 1)

Audio(data, rate=sr)
